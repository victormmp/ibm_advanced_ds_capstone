# %% [markdown]
# ## Imports and setup

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

sns.set(style='darkgrid', palette='pastel')
pd.options.display.max_columns = None

# %%
data = pd.read_csv('../data/raw/data.csv')
data_backup = data.copy()

# %%
data.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.shape
# Out:
# (18207, 89)

# %% [markdown]
# ## Drop Useless Columns

# %%
data.drop(columns=['Photo', 'Unnamed: 0', 'ID', 'Name', 'Flag', 'Club Logo', 'Real Face', 'Joined', 'Loaned From', 'Contract Valid Until', 'Release Clause'], 
            inplace=True)

# %%
data.head(5)
# Out:
#    Age Nationality  Overall  Potential                 Club    Value   Wage  \
# 0   31   Argentina       94         94         FC Barcelona  €110.5M  €565K
# 1   33    Portugal       94         94             Juventus     €77M  €405K
# 2   26      Brazil       92         93  Paris Saint-Germain  €118.5M  €290K
# 3   27       Spain       91         93    Manchester United     €72M  €260K
# 4   27     Belgium       91         92      Manchester City    €102M  €355K
#
#    Special Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0     2202           Left                       5.0        4.0          4.0
# 1     2228          Right                       5.0        4.0          5.0
# 2     2143          Right                       5.0        5.0          5.0
# 3     1471          Right                       4.0        3.0          1.0
# 4     2281          Right                       4.0        5.0          4.0
#
# ...

# %% [markdown]
# ## Count Null values

# %%
null = pd.DataFrame(data.isna().sum(), columns=['null_count'])
null['column'] = null.index
null.sort_values(by=['null_count'], inplace=True, ascending=False)
null.reset_index(inplace=True, drop=True)

# %%
plt.rcParams['figure.figsize'] = [20, 20]
ax1 = sns.barplot(data=null, y='column',  x='null_count', orient='h')
for index, row in null.iterrows():
    ax1.text(row.null_count, row.name, row.null_count)
plt.title('Number of null values per column')
plt.show()

# %% [markdown]
# ## Drop rows with many null values

# %%
threshold = int(0.5 * data.shape[1])

data.dropna(thresh=threshold, inplace=True)
data.shape
# Out:
# (18159, 78)

# %% [markdown]
# ## Fix numeric variables cast

# %% [markdown]
# ### Fix Wage and Value

# %%
def fix_currency(data):
    if not data:
        return 0
    value = re.search(r'[\d.]+', data)
    mult = re.search(r'.*\.?\d(\w)', data)
    if not value:
        return 0
    value = float(value.group(0))

    if not mult:
        return value
    mult = mult.group(1)

    if mult == 'M':
        value *= 1e6
    elif mult == 'K':
        value *= 1e3
    
    return value

# %%
data['Wage'] = data[['Wage']].apply(lambda row: fix_currency(row['Wage']), axis=1)
data['Value'] = data[['Value']].apply(lambda row: fix_currency(row['Value']), axis=1)

# %%
data.head(5)
# Out:
#    Age Nationality  Overall  Potential                 Club        Value  \
# 0   31   Argentina       94         94         FC Barcelona  110500000.0
# 1   33    Portugal       94         94             Juventus   77000000.0
# 2   26      Brazil       92         93  Paris Saint-Germain  118500000.0
# 3   27       Spain       91         93    Manchester United   72000000.0
# 4   27     Belgium       91         92      Manchester City  102000000.0
#
#        Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  565000.0     2202           Left                       5.0        4.0
# 1  405000.0     2228          Right                       5.0        4.0
# 2  290000.0     2143          Right                       5.0        5.0
# 3  260000.0     1471          Right                       4.0        3.0
# 4  355000.0     2281          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Position  Jersey Number Height  \
# ...

# %% [markdown]
# ### Fix Height and Weight

# %%
def height_to_cm(data):
    
    if not data:
        return 0
    if not isinstance(data, str) and np.isnan(data):
        return 0

    value = re.search(r"(\d+)'(\d+)", data)
    
    if not value:
        return 0
    try:
        ft = float(value.group(1))
    except:
        ft = 0
    
    try:
        inches = float(value.group(2))
    except:
        inches = 0
    
    return (ft + (inches/12)) * 30.48

# %%
data['Height'] = data['Height'].apply(lambda value: height_to_cm(value))

# %%
def fix_weight(data):
    if not data:
        return 0
    if not isinstance(data, str) and np.isnan(data):
        return 0
    value = re.search(r'\d+', data)
    if value:
        return float(value.group(0))
    return 0

# %%
data['Weight'] = data['Weight'].apply(lambda value: fix_weight(value))

# %%
data.head(5)
# Out:
#    Age Nationality  Overall  Potential                 Club        Value  \
# 0   31   Argentina       94         94         FC Barcelona  110500000.0
# 1   33    Portugal       94         94             Juventus   77000000.0
# 2   26      Brazil       92         93  Paris Saint-Germain  118500000.0
# 3   27       Spain       91         93    Manchester United   72000000.0
# 4   27     Belgium       91         92      Manchester City  102000000.0
#
#        Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  565000.0     2202           Left                       5.0        4.0
# 1  405000.0     2228          Right                       5.0        4.0
# 2  290000.0     2143          Right                       5.0        5.0
# 3  260000.0     1471          Right                       4.0        3.0
# 4  355000.0     2281          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Position  Jersey Number  Height  \
# ...

# %% [markdown]
# ### Treat trait features

# %%
def fix_traits(data):
    if not data:
        return 0
    if not isinstance(data, str) and np.isnan(data):
        return 0
    value = re.search(r'\d+', data)
    if value:
        return float(value.group(0))

# %%
cols = ['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

for col in cols:
    data[col] = data[col].apply(lambda value: fix_traits(value))

# %%
data.head(5)
# Out:
#    Age Nationality  Overall  Potential                 Club        Value  \
# 0   31   Argentina       94         94         FC Barcelona  110500000.0
# 1   33    Portugal       94         94             Juventus   77000000.0
# 2   26      Brazil       92         93  Paris Saint-Germain  118500000.0
# 3   27       Spain       91         93    Manchester United   72000000.0
# 4   27     Belgium       91         92      Manchester City  102000000.0
#
#        Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  565000.0     2202           Left                       5.0        4.0
# 1  405000.0     2228          Right                       5.0        4.0
# 2  290000.0     2143          Right                       5.0        5.0
# 3  260000.0     1471          Right                       4.0        3.0
# 4  355000.0     2281          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Position  Jersey Number  Height  \
# ...

# %% [markdown]
# ## Treat Missing Values

# %%
for col in data.columns:
    if np.issubdtype(data[col].dtype, np.number):
        data[col].fillna(0, inplace=True)
        data[col] = data[col].astype(np.float64)
    else:
        data[col].fillna('null', inplace=True)
        data[col] = data[col].astype(np.str)

# %%
data.head(5)
# Out:
#     Age Nationality  Overall  Potential                 Club        Value  \
# 0  31.0   Argentina     94.0       94.0         FC Barcelona  110500000.0
# 1  33.0    Portugal     94.0       94.0             Juventus   77000000.0
# 2  26.0      Brazil     92.0       93.0  Paris Saint-Germain  118500000.0
# 3  27.0       Spain     91.0       93.0    Manchester United   72000000.0
# 4  27.0     Belgium     91.0       92.0      Manchester City  102000000.0
#
#        Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  565000.0   2202.0           Left                       5.0        4.0
# 1  405000.0   2228.0          Right                       5.0        4.0
# 2  290000.0   2143.0          Right                       5.0        5.0
# 3  260000.0   1471.0          Right                       4.0        3.0
# 4  355000.0   2281.0          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Position  Jersey Number  Height  \
# ...

# %%
null = pd.DataFrame(data.isna().sum(), columns=['null_count'])
null['column'] = null.index
null.sort_values(by=['null_count'], inplace=True, ascending=False)
null.reset_index(inplace=True, drop=True)
plt.rcParams['figure.figsize'] = [10, 20]
ax1 = sns.barplot(data=null, y='column',  x='null_count', orient='h')
for index, row in null.iterrows():
    ax1.text(row.null_count, row.name, row.null_count)
plt.title('Number of null values per column')
plt.show()

# %% [markdown]
# ## Data Analysis

# %%
[col for col in data.columns if not np.issubdtype(data[col].dtype, np.number)]
# Out:
# ['Nationality', 'Club', 'Preferred Foot', 'Work Rate', 'Body Type', 'Position']

# %%
def get_categorical_info(parameter, size=[10,5], labels=True, axis_rotation=0):
    plt.rcParams['figure.figsize'] = size
    df = Counter(data[parameter])
    df = [{parameter: col, 'occurrences': ins} for col, ins in df.items()]
    df = sorted(df, key=lambda x: x['occurrences'], reverse=True)
    df = pd.DataFrame(df)
    df = df.dropna().reset_index(drop=True)
    print("Number of null values")
    print(data[parameter].isna().sum())
    ax = sns.barplot(data=df, x=parameter, y='occurrences')
    plt.title(parameter.capitalize())
    if labels:
        for index, row in df.iterrows():
            ax.text(row.name, row.occurrences, row.occurrences, ha='center', va='bottom', rotation=axis_rotation)
    if axis_rotation:
        plt.xticks(rotation=axis_rotation)
    plt.show()

# %%
get_categorical_info('Nationality', size=[30, 5], axis_rotation=90)
# Out:
# Number of null values
# 0

# %%
get_categorical_info('Club', size=[30, 5], axis_rotation=90)
# Out:
# Number of null values
# 0

# %%
get_categorical_info('Preferred Foot')
# Out:
# Number of null values
# 0

# %%
get_categorical_info('Work Rate', axis_rotation=45)
# Out:
# Number of null values
# 0

# %%
get_categorical_info('Body Type', axis_rotation=45)
# Out:
# Number of null values
# 0

# %%
get_categorical_info('Position', size=[20, 5])
# Out:
# Number of null values
# 0

# %%
data.describe()
# Out:
#                 Age       Overall     Potential         Value           Wage  \
# count  18159.000000  18159.000000  18159.000000  1.815900e+04   18159.000000
# mean      25.122529     66.249904     71.319126  2.416131e+06    9752.574481
# std        4.670568      6.914613      6.134420  5.601319e+06   22024.397597
# min       16.000000     46.000000     48.000000  0.000000e+00       0.000000
# 25%       21.000000     62.000000     67.000000  3.000000e+05    1000.000000
# 50%       25.000000     66.000000     71.000000  6.750000e+05    3000.000000
# 75%       28.000000     71.000000     75.000000  2.000000e+06    9000.000000
# max       45.000000     94.000000     95.000000  1.185000e+08  565000.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18159.000000              18159.000000  18159.000000  18159.000000
# mean    1597.903959                  1.113222      2.947299      2.361308
# ...

# %%
data.to_csv('data/processed/0_cleaned.csv', index_label=False)
